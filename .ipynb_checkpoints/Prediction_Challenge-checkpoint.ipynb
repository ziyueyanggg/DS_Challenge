# %% [markdown]
# # 1. Data Preperation, Preprocessing and Cleaning

# %% [markdown]
# ## 1.1 Import Libraries and Load Datasets

# %%
import pandas as pd
import numpy as np
import math
import utm
import requests

# %%
df = pd.read_excel("Households_Data.xlsx", sheet_name='Hogares')

# %%
dictionary = pd.read_excel("Households_Data.xlsx", sheet_name='Dictionary')

# %% [markdown]
# ## 1.2 Identify Column Data Types

# %% [markdown]
# Knowing the type of data in each column not only helps one understand the data better, but is also important to selecting the suitable machine learning algorithms later. In this section, we would like to take a closer look at the `dictionary` dataset, and identify which columns are categorical data and which are continuous data from its descriptions.

# %%
dictionary
# Out:
#                     Variable  \
# 0                      Hogar
# 1                    EXCLUIR
# 2             paraValidacion
# 3                     Sector
# 4                  DirCoordX
# 5                  DirCoordY
# 6                   MontoArr
# 7               IngresoHogar
# 8                     Factor
# 9                AnosEstudio
# 10                     CLASE
# 11   Sup_Prom_Constr_Hab_EOD
# 12        Calid_EOD_norm_inv
# 13            DensConstr_EOD
# 14      Dist_est_Metro_MC_KM
# 15   Dist_salida_Autop_MC_KM
# 16           Tiempo_Com_Stgo
# 17  Ingreso_Promedio_Zona_MM
# 18     Acc_Comercio_tpte_pub
# 19    Acc_Educacion_tpte_pub
# 20   Acc_Habitacion_tpte_pub
# 21    Acc_Industria_tpte_pub
# 22    Acc_Servicios_tpte_pub
# 23         Acc_Comercio_auto
# 24        Acc_Educacion_auto
# 25       Acc_Habitacion_auto
# 26        Acc_Industria_auto
# 27        Acc_Servicios_auto
# 28                  CLUSTER7
# 29                  CLUSTER2
#
#                                           Description  \
# 0                                     ID of Household
# 1                             Exclude from estimation
# 2                               sample for validation
# 3   Exogenous sector (7 sectors used for exogenous...
# 4                                    UTM coordinate X
# 5                                    UTM coordinate Y
# 6                Monthly dwelling rent (Chilean Peso)
# 7                     Household income (Chilean Peso)
# 8             Expansion factor of household in survey
# 9      Years of formal Education of head of household
# 10  1 : less than 12 years ; 2 : between 12 and 15...
# 11  Average Built surface of residential units in ...
# 12  Average Construction Quality of residential un...
# 13  Built density in zone (built surface divided b...
# 14            Distance to nearest subway station (km)
# 15              Distance to nearest highway exit (km)
# 16                           travel time to CBD (min)
# 17        Average zonal income (Million Chilean Peso)
# 18                Accesibility to Commerce in transit
# 19               Accesibility to Education in transit
# 20            Accesibility to habitational in transit
# 21                Accesibility to Industry in transit
# 22                Accesibility to Services in transit
# 23                    Accesibility to Commerce in car
# 24                   Accesibility to Education in car
# 25                Accesibility to habitational in car
# 26                    Accesibility to Industry in car
# 27                    Accesibility to Services in car
# 28                 Cluster clasification (7 clusters)
# 29                 Cluster clasification (2 clusters)
#
#                                        Used in Model?
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3         YES (Segmentation in Exogenous Zones Model)
# 4                                                 NaN
# 5                                                 NaN
# 6                           YES (Likelihood function)
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                          YES (Likelihood function)
# 11                                  YES (DP function)
# 12                                                NaN
# 13  YES (Segmentation function in Latent class mod...
# 14                                  YES (DP function)
# 15                                  YES (DP function)
# 16                                  YES (DP function)
# 17  YES (Segmentation function in Latent class mod...
# 18                                  YES (DP function)
# 19                                                NaN
# 20                                                NaN
# 21                                  YES (DP function)
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28              YES (Segmentation in 7 cluster model)
# 29              YES (Segmentation in 2 cluster model)

# %% [markdown]
# From the description column, we would make an informed guess about which columns are categorical and which are continuous.
# <br>
# <br>
# Our guess is `{Hogar, EXCLUIR, paraValidacion, Sector, CLASE, CLUSTER7, CLUSTER2}` are categorical.

# %%
categorical_1=['Hogar', 'EXCLUIR', 'paraValidacion', 
               'Sector', 'CLASE', 'CLUSTER7', 'CLUSTER2']

# %% [markdown]
# From the description of the dataset, it is not always easy to distinguish categorical features from continuous ones. Therefore, we decide to examine the unique values in the dataset.
# <br>
# <br>
# This is based on the idea that the number of unique values in a column would, in general (not always), indicates whether that column is of categorical data type or continuous data type.

# %%
for c in df.columns:
    print(c + " has " + str(df[c].nunique()) + " unique values")
# Out:
# Hogar has 18264 unique values
# EXCLUIR has 2 unique values
# paraValidacion has 2 unique values
# Sector has 7 unique values
# DirCoordX has 16940 unique values
# DirCoordY has 16930 unique values
# MontoArr has 4432 unique values
# IngresoHogar has 12905 unique values
# Factor has 6433 unique values
# AnosEstudio has 23 unique values
# CLASE has 4 unique values
# Sup_Prom_Constr_Hab_EOD has 452 unique values
# Calid_EOD_norm_inv has 7 unique values
# DensConstr_EOD has 421 unique values
# Dist_est_Metro_MC_KM has 16952 unique values
# Dist_salida_Autop_MC_KM has 16952 unique values
# Tiempo_Com_Stgo has 98 unique values
# Ingreso_Promedio_Zona_MM has 789 unique values
# Acc_Comercio_tpte_pub has 631 unique values
# Acc_Educacion_tpte_pub has 631 unique values
# Acc_Habitacion_tpte_pub has 631 unique values
# Acc_Industria_tpte_pub has 631 unique values
# Acc_Servicios_tpte_pub has 631 unique values
# Acc_Comercio_auto has 637 unique values
# Acc_Educacion_auto has 635 unique values
# Acc_Habitacion_auto has 637 unique values
# Acc_Industria_auto has 636 unique values
# Acc_Servicios_auto has 636 unique values
# CLUSTER7 has 7 unique values
# CLUSTER2 has 2 unique values

# %% [markdown]
# After observing the number of unique values in each column, we update our list of categorical features and it now includes: `{EXCLUIR, paraValidacion, Sector, CLASE, Calid_EOD_norm_inv, CLUSTER7, CLUSTER2}` are categorical.

# %%
categorical_2=['EXCLUIR', 'paraValidacion', 'Sector', 'CLASE', 
               'Calid_EOD_norm_inv', 'CLUSTER7', 'CLUSTER2']

# %% [markdown]
# For columns that appear in both `categorical_1` and `categorical_2 lists`, we will take them as categorical data. We will take a closer look at the rest of the columns that only appear in one of the lists.

# %%
# in categorical_1 but not in categorical_2
set(categorical_1)-set(categorical_2)
# Out:
# {'Hogar'}

# %% [markdown]
# `Hogar` is the housing ID which is by definition categorical but we will omit it because ID is just a serial number which will not add insight in the predictive analysis

# %%
# in categorical_2 but not in categorical_1
set(categorical_2)-set(categorical_1)
# Out:
# {'Calid_EOD_norm_inv'}

# %%
df['Calid_EOD_norm_inv'].unique().tolist()
# Out:
# [0.98, 1.0, 0.78, 0.93, 0.36, 0.55, 0.0]

# %% [markdown]
# It seems that `Calid_EOD_norm_inv` is continuous. Indeed, from the description it can be seen that Average Construction Quality should indeed be a continuous feature. Thus, we treat this column as continuous.

# %%
categorical = set(categorical_1 + categorical_2)
categorical -= {'Hogar','Calid_EOD_norm_inv'}
categorical = list(categorical)

# %% [markdown]
# Thus, we reach the conclusion that the following columns are categorical:

# %%
categorical
# Out:
# ['CLUSTER7', 'CLASE', 'EXCLUIR', 'CLUSTER2', 'paraValidacion', 'Sector']

# %% [markdown]
# The rest of the columns are thus continuous

# %% [markdown]
# ## 1.3 Drop Irrelevant Columns

# %% [markdown]
# After close inspection on the variable descriptions, we decided to remove columns which have limited contribution to the prediction task. We will remove:
#
# * `Hogar`, as it is just the ID of the data entries
# * `paraValidacion`, as it seems to be used for validation for some other studies, which makes this column have little relevance to our task.

# %%
df = df.drop(['Hogar', 'paraValidacion'], axis=1)

# %% [markdown]
# Update our `categorical` list too:

# %%
categorical.remove('paraValidacion')

# %%
categorical
# Out:
# ['CLUSTER7', 'CLASE', 'EXCLUIR', 'CLUSTER2', 'Sector']

# %% [markdown]
# ## 1.4 Rename Columns

# %% [markdown]
# The current column names are difficult to understand, so we rename them.

# %%
df = df.rename(columns={'EXCLUIR': 'excluded_from_estimation',
                   'Sector': 'exogenous_sector', 
                   'DirCoordX' : 'UTM_East',
                   'DirCoordY' : 'UTM_North', 
                   'MontoArr' : 'monthly_rent',
                   'IngresoHogar' : 'household_income', 
                   'Factor' : 'survey_factor',
                   'AnosEstudio' : 'education_years', 
                   'CLASE' : 'type',
                   'Sup_Prom_Constr_Hab_EOD': 'built_surface',
                   'Calid_EOD_norm_inv' : 'construction_quality',
                   'DensConstr_EOD' : 'build_density', 
                   'Dist_est_Metro_MC_KM' : 'subway_dis',
                   'Dist_salida_Autop_MC_KM' : 'highway_dis', 
                   'Tiempo_Com_Stgo' : 'time_CBD',
                   'Ingreso_Promedio_Zona_MM' : 'avg_zone_income',
                   'Acc_Comercio_tpte_pub' : 'commerce_transit', 
                   'Acc_Educacion_tpte_pub' : 'eduction_transit',
                   'Acc_Habitacion_tpte_pub' : 'habitational_transit', 
                   'Acc_Industria_tpte_pub' : 'industry_transit',
                   'Acc_Servicios_tpte_pub' : 'service_transit',
                   'Acc_Comercio_auto' : 'commerce_car',
                   'Acc_Educacion_auto' : 'education_car',
                   'Acc_Habitacion_auto' : 'education_car',
                   'Acc_Habitacion_auto' : 'habitational_car',
                   'Acc_Industria_auto' : 'industry_car',
                   'Acc_Servicios_auto' : 'service_car',
                   'CLUSTER7' : 'cluster_7',
                   'CLUSTER2' : 'cluster_2'
                  })

# %% [markdown]
# Lastly, we need to update our categorical list.

# %%
# update categorical list
print("original : ")
print(categorical)
categorical = ['cluster_7', 'type', 'excluded_from_estimation', 'cluster_2', 'exogenous_sector']
print("updated : ")
print(categorical)
# Out:
# original :
# ['CLUSTER7', 'CLASE', 'EXCLUIR', 'CLUSTER2', 'Sector']
# updated :
# ['cluster_7', 'type', 'excluded_from_estimation', 'cluster_2', 'exogenous_sector']

# %% [markdown]
# ## 1.5 Handle Missing Values
# Check if the dataset contains any missing value in its entries, and handle these missing values if they exist.

# %%
# check for NaNs
for column in df.columns:
    print("column {} has {} null value".format(column, df[column].isnull().sum().sum()))
# Out:
# column excluded_from_estimation has 0 null value
# column exogenous_sector has 0 null value
# column UTM_East has 0 null value
# column UTM_North has 0 null value
# column monthly_rent has 0 null value
# column household_income has 0 null value
# column survey_factor has 0 null value
# column education_years has 0 null value
# column type has 0 null value
# column built_surface has 0 null value
# column construction_quality has 0 null value
# column build_density has 0 null value
# column subway_dis has 0 null value
# column highway_dis has 0 null value
# column time_CBD has 0 null value
# column avg_zone_income has 0 null value
# column commerce_transit has 0 null value
# column eduction_transit has 0 null value
# column habitational_transit has 0 null value
# column industry_transit has 0 null value
# column service_transit has 0 null value
# column commerce_car has 0 null value
# column education_car has 0 null value
# column habitational_car has 0 null value
# column industry_car has 0 null value
# column service_car has 0 null value
# column cluster_7 has 0 null value
# column cluster_2 has 0 null value

# %% [markdown]
# It can be seen from the result above that this dataset does not have any NaNs.

# %% [markdown]
# Now, check if there are any entry with a value of -99 (meaning that the respondent of the survey didn't answer that question)

# %%
# find all columns that contain the value -99
no_response_col = []
for col in df.columns:
    if df[col].isin([-99]).any():
        no_response_col.append(col)
no_response_col
# Out:
# ['education_years',
#  'type',
#  'time_CBD',
#  'commerce_transit',
#  'eduction_transit',
#  'habitational_transit',
#  'industry_transit',
#  'service_transit',
#  'commerce_car',
#  'education_car',
#  'habitational_car',
#  'industry_car',
#  'service_car']

# %%
# find the indices of the rows containing at least one entry that equals to -99
index_list = []
for index, row in df.iterrows():
    for col in no_response_col:
        if row[col] == -99:
            index_list.append(index)
            continue

# %%
# obtain the dataframe in which at least one value in a row is -99
no_response_df = df[df.index.isin(index_list)]
no_response_df
# Out:
#        excluded_from_estimation  exogenous_sector     UTM_East    UTM_North  \
# 20                            1                 7  341877.0000  6270590.000
# 473                           1                 2  340618.1836  6292159.436
# 571                           1                 2  339850.7695  6301456.322
# 1351                          1                 1  345723.6978  6304693.506
# 1425                          1                 5  346330.7654  6286289.991
# 1526                          1                 6  357176.7954  6295599.982
# 1772                          1                 6  351826.1108  6287711.495
# 1780                          1                 5  343490.3392  6286980.431
# 2712                          1                 7  327182.8958  6265116.542
# 2734                          1                 7  327426.2079  6265272.163
# 2897                          1                 5  346620.9457  6289111.694
# 2962                          1                 5  344554.5306  6289123.455
# 2965                          1                 5  344976.4600  6289324.825
# 2968                          1                 5  346343.6049  6288548.343
# 3002                          1                 5  345962.4474  6288584.987
# 3009                          1                 5  344604.2929  6288886.313
# 3050                          1                 5  344686.8158  6289109.890
# 3419                          1                 6  351978.6066  6289163.637
# 3676                          1                 6  353517.7072  6286909.811
# 3890                          1                 6  351903.3234  6286251.827
# 4053                          1                 6  350435.4320  6285183.524
# 4728                          1                 5  346363.9199  6285544.996
# 5047                          1                 3  357607.7082  6298461.686
# 5050                          1                 3  357607.7082  6298461.686
# 5328                          1                 3  353192.7841  6300674.697
# 5339                          1                 3  360118.1414  6304904.782
# 5356                          1                 3  353630.0798  6300459.841
# 5363                          1                 3  356317.2620  6303875.300
# 5365                          1                 3  353596.1517  6301705.729
# 5368                          1                 3  351446.5250  6301070.151
# ...                         ...               ...          ...          ...
# 17938                         1                 3  351775.0228  6302687.206
# 17944                         1                 3  353575.6887  6303410.907
# 18118                         1                 3  354350.7887  6297859.140
# 18119                         1                 3  354368.4278  6297423.087
# 18120                         1                 3  355333.3994  6299289.882
# 18127                         1                 3  355551.6767  6298789.833
# 18128                         1                 3  355474.9016  6298669.911
# 18129                         1                 3  355447.4389  6298740.482
# 18130                         1                 3  355447.4389  6298740.482
# 18132                         1                 3  355474.9016  6298669.911
# 18188                         1                 3  378143.7239  6309155.052
# 18191                         1                 3  379772.6545  6310667.502
# 18192                         1                 3  379772.6545  6310667.502
# 18193                         1                 3  379772.6545  6310667.502
# 18194                         1                 3  379772.6545  6310667.502
# 18195                         1                 3  379773.0000  6310668.000
# 18196                         1                 3  379772.6545  6310667.502
# 18197                         1                 3  379772.6545  6310667.502
# 18201                         1                 3  379709.0000  6310812.000
# 18205                         1                 3  379707.2600  6310803.700
# 18209                         1                 3  377501.7439  6308679.414
# 18210                         1                 3  377501.7439  6308679.414
# 18211                         1                 3  377501.7439  6308679.414
# 18224                         1                 3  356247.9601  6305516.589
# 18225                         1                 3  356254.9203  6305455.139
# 18226                         1                 3  356836.0096  6305032.540
# 18227                         1                 3  357183.0222  6305192.601
# 18228                         1                 3  357115.7598  6305147.912
# 18231                         1                 3  356475.1362  6305682.881
# 18233                         1                 2  345179.5258  6293496.599
#
#        monthly_rent  household_income  survey_factor  education_years  type  \
# 20           193981            600000      15.152181              -99   -99
# 473          160000                 0      58.908264              -99   -99
# 571          150000            111590      76.265007              -99   -99
# 1351         130000            903627     105.309120              -99   -99
# 1425          80000             91205     146.960342              -99   -99
# 1526         132729             30193     146.835587              -99   -99
# 1772         153907             45829      92.318352              -99   -99
# 1780         112329            295741      70.119965              -99   -99
# 2712          90000            650000      21.323198              -99   -99
# 2734          80000             86061      35.299995              -99   -99
# 2897         139720            128167      59.342152              -99   -99
# 2962         158376            158796     185.521118              -99   -99
# 2965         100000             74124     120.562073              -99   -99
# 2968         179407            120000     127.780060              -99   -99
# 3002         400000            859269     268.040070              -99   -99
# 3009         157148            132236     120.562073              -99   -99
# 3050         188972            352607      74.058151              -99   -99
# 3419         400000            880000      95.047218              -99   -99
# 3676         200000            736980     115.688866              -99   -99
# 3890         250000            432000      84.231293              -99   -99
# 4053          80000            267000      78.532310              -99   -99
# 4728         100000            690000      68.604820              -99   -99
# 5047         470471           2851663     134.828339              -99   -99
# 5050         347578            691719     119.914238              -99   -99
# 5328         400000            583382     134.377762              -99   -99
# 5339         368425            383184     159.321930              -99   -99
# 5356         494647           1001440     134.133087              -99   -99
# 5363         426155            519103     183.011703              -99   -99
# 5365         356474            785276      63.796185              -99   -99
# 5368         514744           1042461      44.857822              -99   -99
# ...             ...               ...            ...              ...   ...
# 17938        503281            446366     189.202042              -99   -99
# 17944       1000000           2203129     491.959503              -99   -99
# 18118        600000           1320594      66.465584              -99   -99
# 18119        280000            606298      66.465584              -99   -99
# 18120        425046           1129645      84.231506              -99   -99
# 18127        424524           2693391     101.347176              -99   -99
# 18128        350000           1421159      37.438061              -99   -99
# 18129        378526            726834      90.596672              -99   -99
# 18130        373565            748742     100.593468              -99   -99
# 18132        350000           1596589      42.094360              -99   -99
# 18188        246118            201318      22.842304               12     2
# 18191        331537            352524      22.167740               11     1
# 18192        291246            372489      22.167740                9     1
# 18193        256220            448770      22.842304               13     2
# 18194        304914            518503      22.167740                9     1
# 18195        233767            700097      22.842304               10     1
# 18196        270158            258121      22.842304                9     1
# 18197        300000            306953      25.727528                8     1
# 18201        396163            888574      22.167740               16     3
# 18205        245393            287944      22.842304               12     2
# 18209        403308           2410437      22.167740               17     3
# 18210        200000            254604      39.558998                7     1
# 18211        282818            458842      27.802570               11     1
# 18224        531013            338532     146.802643              -99   -99
# 18225        757707           9183850      88.560768              -99   -99
# 18226        686626           1290352     108.025642              -99   -99
# 18227        598215            840535      19.300524              -99   -99
# 18228        916712           1601772     108.025642              -99   -99
# 18231        491733            176004      19.617735              -99   -99
# 18233        300000            514985      43.461647              -99   -99
#
#        built_surface  ...  habitational_transit  industry_transit  \
# 20              75.8  ...            6110.62492         671.08681
# 473             58.0  ...           18595.82690        2345.57027
# 571             41.6  ...           20220.31465        2055.68218
# 1351            38.6  ...           20287.68567        2485.45627
# 1425            50.3  ...           31896.73297        2730.34489
# 1526            41.6  ...           16481.15954         754.33117
# 1772            42.5  ...           31818.42382        1568.82854
# 1780            39.5  ...           29073.79277        2608.05899
# 2712             0.0  ...            1353.46220         172.28472
# 2734             0.0  ...            1353.46220         172.28472
# 2897            53.9  ...           31764.76215        3019.62728
# 2962            54.2  ...           34350.91607        3096.44625
# 2965            54.2  ...           34350.91607        3096.44625
# 2968            54.9  ...           36436.82667        2909.06214
# 3002            66.9  ...           35196.33382        3221.81731
# 3009            54.2  ...           34350.91607        3096.44625
# 3050            54.2  ...           34350.91607        3096.44625
# 3419            71.9  ...           41331.55848        2972.58287
# 3676            49.3  ...           23560.89681        1191.96367
# 3890            50.5  ...           31624.98792        1735.25603
# 4053            26.7  ...           21898.79230        1211.17251
# 4728            31.5  ...           18369.99146        1219.66424
# 5047            99.4  ...           12907.33834         502.22494
# 5050            99.4  ...           12907.33834         502.22494
# 5328            89.7  ...           36158.56722        2118.63539
# 5339            71.6  ...           19821.39130        1002.63458
# 5356            94.4  ...           28230.15673        1205.49924
# 5363            70.4  ...           29231.91403        1603.75409
# 5365            90.8  ...           34412.13833        1943.77300
# 5368           109.3  ...           40522.37630        2474.98513
# ...              ...  ...                   ...               ...
# 17938          125.9  ...           24326.03933        1243.58394
# 17944          111.0  ...           25941.96174        1147.43206
# 18118           64.1  ...           26445.57533        1129.13024
# 18119           64.1  ...           26445.57533        1129.13024
# 18120           69.6  ...           21716.56953         758.48425
# 18127           69.0  ...           29553.56373        1463.31062
# 18128           69.0  ...           29553.56373        1463.31062
# 18129           69.0  ...           29553.56373        1463.31062
# 18130           69.0  ...           29553.56373        1463.31062
# 18132           69.0  ...           29553.56373        1463.31062
# 18188           92.0  ...             -99.00000         -99.00000
# 18191           92.0  ...             -99.00000         -99.00000
# 18192           92.0  ...             -99.00000         -99.00000
# 18193           92.0  ...             -99.00000         -99.00000
# 18194           92.0  ...             -99.00000         -99.00000
# 18195           92.0  ...             -99.00000         -99.00000
# 18196           92.0  ...             -99.00000         -99.00000
# 18197           92.0  ...             -99.00000         -99.00000
# 18201           92.0  ...             -99.00000         -99.00000
# 18205           92.0  ...             -99.00000         -99.00000
# 18209           92.0  ...             -99.00000         -99.00000
# 18210           92.0  ...             -99.00000         -99.00000
# 18211           92.0  ...             -99.00000         -99.00000
# 18224           81.6  ...           18734.38838         645.56891
# 18225           81.6  ...           18734.38838         645.56891
# 18226           79.9  ...           19353.63042         835.72731
# 18227           79.9  ...           19353.63042         835.72731
# 18228           79.9  ...           19353.63042         835.72731
# 18231           79.9  ...           19353.63042         835.72731
# 18233           52.4  ...           19665.73737        2436.06171
#
#        service_transit  commerce_car  education_car  habitational_car  \
# 20           719.84272       3036.41        1781.81          30505.65
# 473         1730.19648       6270.54        3631.50          62639.45
# 571         2260.59053       6989.71        3866.75          65484.20
# 1351        2800.63140       6584.60        3617.13          62135.37
# 1425        3518.55023       6317.66        3816.16          64953.69
# 1526        1407.08549       5505.48        3185.88          56497.30
# 1772        2829.39221       6146.96        3743.58          64619.84
# 1780        2964.73310       6938.10        4058.30          68584.75
# 2712         132.02718       1048.44         613.41          10859.53
# 2734         132.02718       1048.44         613.41          10859.53
# 2897        3752.31820       6735.28        3951.83          65659.41
# 2962        3752.86005       7378.67        4286.66          71997.51
# 2965        3752.86005       7378.67        4286.66          71997.51
# 2968        3692.99823       6896.73        4080.49          69282.05
# 3002        3752.09353       6953.08        4113.40          69784.83
# 3009        3752.86005       7378.67        4286.66          71997.51
# 3050        3752.86005       7378.67        4286.66          71997.51
# 3419        4278.32039       6374.16        3855.39          66588.74
# 3676        2252.80305       5346.54        3278.56          57042.04
# 3890        2843.52826       5729.73        3539.16          61213.10
# 4053        1661.07209       5564.72        3451.76          59757.27
# 4728        1067.49532       5740.02        3538.92          60501.48
# 5047        1228.70506       5615.61        3172.56          56452.81
# 5050        1228.70506       5615.61        3172.56          56452.81
# 5328        5870.50751       7067.28        3874.49          68530.48
# 5339        2771.02667       5169.99        2812.09          49304.95
# 5356        3240.62202       7098.72        3916.99          69264.22
# 5363        4467.39394       6161.60        3364.84          59913.19
# 5365        5442.09143       6820.96        3727.15          66115.47
# 5368        6499.02445       7479.83        4071.07          71215.14
# ...                ...           ...            ...               ...
# 17938       4223.45100       7313.28        3934.22          68300.14
# 17944       3926.24080       7457.63        4023.16          70227.70
# 18118       2019.89112       6816.44        3903.28          68900.36
# 18119       2019.89112       6816.44        3903.28          68900.36
# 18120       2385.15319       6440.37        3592.77          63790.77
# 18127       3409.62005       6622.16        3750.26          66300.41
# 18128       3409.62005       6622.16        3750.26          66300.41
# 18129       3409.62005       6622.16        3750.26          66300.41
# 18130       3409.62005       6622.16        3750.26          66300.41
# 18132       3409.62005       6622.16        3750.26          66300.41
# 18188        -99.00000        -99.00         -99.00            -99.00
# 18191        -99.00000        -99.00         -99.00            -99.00
# 18192        -99.00000        -99.00         -99.00            -99.00
# 18193        -99.00000        -99.00         -99.00            -99.00
# 18194        -99.00000        -99.00         -99.00            -99.00
# 18195        -99.00000        -99.00         -99.00            -99.00
# 18196        -99.00000        -99.00         -99.00            -99.00
# 18197        -99.00000        -99.00         -99.00            -99.00
# 18201        -99.00000        -99.00         -99.00            -99.00
# 18205        -99.00000        -99.00         -99.00            -99.00
# 18209        -99.00000        -99.00         -99.00            -99.00
# 18210        -99.00000        -99.00         -99.00            -99.00
# 18211        -99.00000        -99.00         -99.00            -99.00
# 18224       2593.68339       6402.06        3436.37          60251.48
# 18225       2593.68339       6402.06        3436.37          60251.48
# 18226       2611.91008       6507.05        3513.68          61589.52
# 18227       2611.91008       6507.05        3513.68          61589.52
# 18228       2611.91008       6507.05        3513.68          61589.52
# 18231       2611.91008       6507.05        3513.68          61589.52
# 18233       1986.59162       7773.93        4391.55          72650.33
#
#        industry_car  service_car  cluster_7  cluster_2
# 20          2853.19      3058.03          3          1
# 473         6083.56      6461.99          5          1
# 571         6142.82      7967.46          3          1
# 1351        5610.12      7735.47          2          1
# 1425        5615.28      6275.97          5          1
# 1526        4144.63      5796.40          5          1
# 1772        5250.59      6045.88          2          1
# 1780        6280.98      7144.38          5          1
# 2712        1030.76      1061.18          3          1
# 2734        1030.76      1061.18          3          1
# 2897        6042.60      6978.21          5          1
# 2962        6599.61      7684.77          5          1
# 2965        6599.61      7684.77          5          1
# 2968        6169.21      6969.78          5          1
# 3002        6238.64      7023.88          2          1
# 3009        6599.61      7684.77          5          1
# 3050        6599.61      7684.77          5          1
# 3419        5390.87      6284.64          2          1
# 3676        4424.32      5220.57          2          1
# 3890        4877.73      5599.47          2          1
# 4053        4731.68      5421.59          5          1
# 4728        5053.91      5637.78          5          1
# 5047        3982.73      6104.89          7          2
# 5050        3982.73      6104.89          7          2
# 5328        4981.83      8253.95          6          2
# 5339        3572.54      5939.45          2          1
# 5356        5009.57      8198.70          6          2
# 5363        4184.84      6982.79          6          1
# 5365        4728.51      7913.26          1          2
# 5368        5476.90      8954.24          4          2
# ...             ...          ...        ...        ...
# 17938       5385.72      8729.24          1          2
# 17944       5414.02      8853.12          6          2
# 18118       5106.03      7327.11          2          1
# 18119       5106.03      7327.11          2          1
# 18120       4544.97      7196.31          6          1
# 18127       4834.73      7277.85          2          1
# 18128       4834.73      7277.85          2          1
# 18129       4834.73      7277.85          2          1
# 18130       4834.73      7277.85          2          1
# 18132       4834.73      7277.85          2          1
# 18188        -99.00       -99.00          2          1
# 18191        -99.00       -99.00          2          1
# 18192        -99.00       -99.00          2          1
# 18193        -99.00       -99.00          2          1
# 18194        -99.00       -99.00          2          1
# 18195        -99.00       -99.00          2          1
# 18196        -99.00       -99.00          2          1
# 18197        -99.00       -99.00          2          1
# 18201        -99.00       -99.00          2          1
# 18205        -99.00       -99.00          2          1
# 18209        -99.00       -99.00          2          1
# 18210        -99.00       -99.00          2          1
# 18211        -99.00       -99.00          2          1
# 18224       4524.28      7471.00          7          2
# 18225       4524.28      7471.00          7          2
# 18226       4599.68      7617.50          6          2
# 18227       4599.68      7617.50          6          2
# 18228       4599.68      7617.50          6          2
# 18231       4599.68      7617.50          6          2
# 18233       6923.58      8372.83          5          1
#
# [423 rows x 28 columns]

# %% [markdown]
# calculate the proportion of the dataframe that contains no response (-99)

# %%
len(no_response_df)
# Out:
# 423

# %%
len(no_response_df)/len(df)
# Out:
# 0.023160315374507228

# %% [markdown]
# Proportion of non-response is 0.023 which is relatively small. Thus, we decide to drop the non-response rows to prevent the value -99 from interfering with our predictions.

# %%
df = df.drop(index_list, axis = 0)

# %%
df
# Out:
#        excluded_from_estimation  exogenous_sector     UTM_East    UTM_North  \
# 0                             0                 7  335180.8019  6266420.975
# 1                             0                 7  338410.2114  6265607.141
# 2                             0                 7  327863.8248  6257800.086
# 3                             0                 7  327864.0000  6257800.000
# 4                             0                 7  338480.8152  6267296.941
# 5                             0                 7  338520.4611  6267243.590
# 6                             0                 7  338672.2754  6267348.648
# 7                             0                 7  338923.4993  6266488.784
# 8                             0                 7  339472.5195  6262741.680
# 9                             0                 7  334850.7817  6266124.316
# 10                            0                 7  335866.8423  6266308.101
# 11                            0                 7  338901.5010  6262892.346
# 12                            0                 7  338124.9988  6266113.566
# 13                            0                 7  338672.0894  6266596.355
# 14                            0                 7  338859.8374  6268671.365
# 15                            0                 7  338018.8011  6266424.464
# 16                            0                 7  338713.0790  6265343.155
# 17                            0                 7  338487.6568  6268439.356
# 18                            0                 7  338399.8784  6268318.075
# 19                            0                 7  338756.5334  6266656.237
# 21                            0                 7  337881.5539  6266177.896
# 22                            0                 7  338821.1269  6266668.492
# 23                            0                 7  339001.0763  6268411.752
# 24                            0                 7  339333.9988  6266135.413
# 25                            0                 7  335115.4429  6266056.673
# 26                            0                 7  338384.8857  6265230.677
# 27                            0                 7  333732.5499  6261246.379
# 28                            0                 7  335939.7440  6266985.337
# 29                            0                 7  337941.5627  6266104.023
# 30                            0                 7  338788.3062  6266701.254
# ...                         ...               ...          ...          ...
# 18234                         0                 2  344327.7707  6293609.778
# 18235                         0                 2  344092.3253  6292651.427
# 18236                         0                 2  345486.9334  6294409.706
# 18237                         0                 2  345512.3045  6294386.709
# 18238                         0                 2  343957.6829  6291668.744
# 18239                         0                 2  345059.2223  6293042.130
# 18240                         0                 2  345326.1715  6294053.753
# 18241                         0                 2  345301.1119  6294057.344
# 18242                         0                 7  324482.7084  6280267.795
# 18243                         0                 7  324405.2675  6280365.552
# 18244                         0                 7  324391.3898  6280413.775
# 18245                         0                 7  324356.1505  6280381.404
# 18246                         0                 7  324367.4691  6280433.025
# 18247                         0                 7  324253.9681  6280522.303
# 18248                         0                 7  324479.7206  6280431.253
# 18249                         0                 7  324482.7084  6280267.795
# 18250                         0                 7  325364.5734  6280297.297
# 18251                         0                 7  325381.6153  6280289.176
# 18252                         1                 7  325247.0057  6280351.067
# 18253                         0                 7  325460.0000  6280490.000
# 18254                         0                 7  325430.6623  6280363.837
# 18255                         0                 7  325405.9747  6280373.815
# 18256                         0                 7  325399.1763  6280364.817
# 18257                         0                 7  338662.7272  6267035.680
# 18258                         0                 7  338657.6589  6267033.931
# 18259                         0                 7  339104.1011  6263063.925
# 18260                         0                 2  338539.1741  6299539.203
# 18261                         0                 2  338563.2201  6299580.118
# 18262                         0                 5  349410.2812  6289668.962
# 18263                         0                 5  349370.5635  6289594.916
#
#        monthly_rent  household_income  survey_factor  education_years  type  \
# 0            100000            450845     136.393738               11     1
# 1            120000           1019369      73.843597               11     1
# 2             70000             80000     180.722809               10     1
# 3             80000            559259     150.379059               14     2
# 4            117771            710309     122.001518               12     2
# 5            120000            415053     122.001518                9     1
# 6             90000            231227      98.045624               15     2
# 7            140000             79133     114.663483               11     1
# 8            132271           1334494     118.012085               12     2
# 9            138696           1543874     108.940498               14     2
# 10           150000            278046     139.501297               10     1
# 11           120000            619535     110.427055               17     3
# 12           112553             92754     114.663483               12     2
# 13           150000           1200000     270.516083               14     2
# 14           120000            280000     204.814835               12     2
# 15           120000            184068     114.663483                8     1
# 16           170000            274156     110.427055               12     2
# 17            90000            643128      95.274445               11     1
# 18           150000            120000     100.279488               12     2
# 19           100000            403936      83.442345               12     2
# 21           260000           1586807     116.353302               12     2
# 22           130000            182046     119.283798               11     1
# 23            90000            163929     104.075729               12     2
# 24           118854            468043     119.004265                9     1
# 25           200000            526495      93.285820               17     3
# 26           120000            464941      86.235573               11     1
# 27           120000            730852     183.386124               12     2
# 28           120000            348617     106.513710               12     2
# 29           150000            228546     108.940498               12     2
# 30           120000            195529     101.757294               16     3
# ...             ...               ...            ...              ...   ...
# 18234        100000           1050000     152.853699                6     1
# 18235         80000            400000      93.476822                6     1
# 18236        200000            282358      91.479095               11     1
# 18237        150000            605779     104.425507               10     1
# 18238        100000            500000      69.703918               16     3
# 18239         70000            130000      48.107174                7     1
# 18240        138864            431957      77.119125               12     2
# 18241        150000             92066      35.973270               12     2
# 18242        250000            180000      81.256096                7     1
# 18243        250000            721411      46.436039               10     1
# 18244        250000           2232622      56.111351                7     1
# 18245        300000            884568      84.156906               14     2
# 18246        300000            513433      81.256096               14     2
# 18247        400000           2553656      65.780464               14     2
# 18248        100000            172674      63.533081                5     1
# 18249        250000            648878      81.256096               14     2
# 18250        140000            450000     100.808945               12     2
# 18251        150000            690000      55.624287               10     1
# 18252        140000            700000      67.214058               15     2
# 18253        150000            650000      73.680771               11     1
# 18254        160000            520000     100.808945               11     1
# 18255        150000            285000      76.104340               12     2
# 18256        150000            320000      76.104340               12     2
# 18257        250000            575164      81.583549               12     2
# 18258        150000            180000     104.075729               10     1
# 18259        100000            300000      75.526031               10     1
# 18260        140000            695186     174.348663               12     2
# 18261        200000            396715      71.358963               11     1
# 18262         80000            318005      68.410446               12     2
# 18263         80000            140007     231.671707                9     1
#
#        built_surface  ...  habitational_transit  industry_transit  \
# 0               53.8  ...            6110.62492         671.08681
# 1               59.6  ...            6110.62492         671.08681
# 2               59.5  ...            6110.62492         671.08681
# 3               59.5  ...            6110.62492         671.08681
# 4               43.6  ...            6110.62492         671.08681
# 5               43.6  ...            6110.62492         671.08681
# 6               43.6  ...            6110.62492         671.08681
# 7               53.8  ...            6110.62492         671.08681
# 8               59.6  ...            6110.62492         671.08681
# 9               53.8  ...            6110.62492         671.08681
# 10              53.8  ...            6110.62492         671.08681
# 11              59.6  ...            6110.62492         671.08681
# 12              53.8  ...            6110.62492         671.08681
# 13              43.6  ...            6110.62492         671.08681
# 14              21.4  ...            6110.62492         671.08681
# 15              53.8  ...            6110.62492         671.08681
# 16              59.6  ...            6110.62492         671.08681
# 17              43.6  ...            6110.62492         671.08681
# 18              43.6  ...            6110.62492         671.08681
# 19              43.6  ...            6110.62492         671.08681
# 21              53.8  ...            6110.62492         671.08681
# 22              43.6  ...            6110.62492         671.08681
# 23              43.6  ...            6110.62492         671.08681
# 24              53.8  ...            6110.62492         671.08681
# 25              53.8  ...            6110.62492         671.08681
# 26              59.6  ...            6110.62492         671.08681
# 27              59.5  ...            6110.62492         671.08681
# 28              53.8  ...            6110.62492         671.08681
# 29              53.8  ...            6110.62492         671.08681
# 30              43.6  ...            6110.62492         671.08681
# ...              ...  ...                   ...               ...
# 18234           46.7  ...           23548.87113        2906.93874
# 18235           41.3  ...           24242.16689        2858.97529
# 18236           72.4  ...           32449.06096        3831.10271
# 18237           53.1  ...           29303.34411        3304.04218
# 18238           41.3  ...           22502.75697        2526.66670
# 18239           52.4  ...           19665.73737        2436.06171
# 18240           52.4  ...           19665.73737        2436.06171
# 18241           52.4  ...           19665.73737        2436.06171
# 18242           53.5  ...            2967.30967         231.58675
# 18243           53.5  ...            2967.30967         231.58675
# 18244           53.5  ...            2967.30967         231.58675
# 18245           53.5  ...            2967.30967         231.58675
# 18246           53.5  ...            2967.30967         231.58675
# 18247           53.5  ...            2967.30967         231.58675
# 18248           53.5  ...            2967.30967         231.58675
# 18249           53.5  ...            2967.30967         231.58675
# 18250           52.1  ...            2967.30967         231.58675
# 18251           52.1  ...            2967.30967         231.58675
# 18252           52.1  ...            2967.30967         231.58675
# 18253           52.1  ...            2967.30967         231.58675
# 18254           52.1  ...            2967.30967         231.58675
# 18255           52.1  ...            2967.30967         231.58675
# 18256           52.1  ...            2967.30967         231.58675
# 18257           43.6  ...            6110.62492         671.08681
# 18258           43.6  ...            6110.62492         671.08681
# 18259           59.6  ...            6110.62492         671.08681
# 18260           48.3  ...           26638.37017        2667.49616
# 18261           48.3  ...           26638.37017        2667.49616
# 18262           40.6  ...           36601.48715        3033.01343
# 18263           34.1  ...           24049.00136        2103.14796
#
#        service_transit  commerce_car  education_car  habitational_car  \
# 0            719.84272       3036.41        1781.81          30505.65
# 1            719.84272       3036.41        1781.81          30505.65
# 2            719.84272       3036.41        1781.81          30505.65
# 3            719.84272       3036.41        1781.81          30505.65
# 4            719.84272       3036.41        1781.81          30505.65
# 5            719.84272       3036.41        1781.81          30505.65
# 6            719.84272       3036.41        1781.81          30505.65
# 7            719.84272       3036.41        1781.81          30505.65
# 8            719.84272       3036.41        1781.81          30505.65
# 9            719.84272       3036.41        1781.81          30505.65
# 10           719.84272       3036.41        1781.81          30505.65
# 11           719.84272       3036.41        1781.81          30505.65
# 12           719.84272       3036.41        1781.81          30505.65
# 13           719.84272       3036.41        1781.81          30505.65
# 14           719.84272       3036.41        1781.81          30505.65
# 15           719.84272       3036.41        1781.81          30505.65
# 16           719.84272       3036.41        1781.81          30505.65
# 17           719.84272       3036.41        1781.81          30505.65
# 18           719.84272       3036.41        1781.81          30505.65
# 19           719.84272       3036.41        1781.81          30505.65
# 21           719.84272       3036.41        1781.81          30505.65
# 22           719.84272       3036.41        1781.81          30505.65
# 23           719.84272       3036.41        1781.81          30505.65
# 24           719.84272       3036.41        1781.81          30505.65
# 25           719.84272       3036.41        1781.81          30505.65
# 26           719.84272       3036.41        1781.81          30505.65
# 27           719.84272       3036.41        1781.81          30505.65
# 28           719.84272       3036.41        1781.81          30505.65
# 29           719.84272       3036.41        1781.81          30505.65
# 30           719.84272       3036.41        1781.81          30505.65
# ...                ...           ...            ...               ...
# 18234       2292.51618       7453.63        4231.24          70690.87
# 18235       2246.47011       7481.99        4252.66          71167.26
# 18236       4879.55138       8053.78        4503.08          74341.32
# 18237       3910.18418       7327.48        4146.17          68489.11
# 18238       2110.42776       7083.29        4073.61          68417.02
# 18239       1986.59162       7773.93        4391.55          72650.33
# 18240       1986.59162       7773.93        4391.55          72650.33
# 18241       1986.59162       7773.93        4391.55          72650.33
# 18242        188.26424       2436.12        1417.51          25057.11
# 18243        188.26424       2436.12        1417.51          25057.11
# 18244        188.26424       2436.12        1417.51          25057.11
# 18245        188.26424       2436.12        1417.51          25057.11
# 18246        188.26424       2436.12        1417.51          25057.11
# 18247        188.26424       2436.12        1417.51          25057.11
# 18248        188.26424       2436.12        1417.51          25057.11
# 18249        188.26424       2436.12        1417.51          25057.11
# 18250        188.26424       2436.12        1417.51          25057.11
# 18251        188.26424       2436.12        1417.51          25057.11
# 18252        188.26424       2436.12        1417.51          25057.11
# 18253        188.26424       2436.12        1417.51          25057.11
# 18254        188.26424       2436.12        1417.51          25057.11
# 18255        188.26424       2436.12        1417.51          25057.11
# 18256        188.26424       2436.12        1417.51          25057.11
# 18257        719.84272       3036.41        1781.81          30505.65
# 18258        719.84272       3036.41        1781.81          30505.65
# 18259        719.84272       3036.41        1781.81          30505.65
# 18260       2815.13223       5968.57        3338.36          57762.43
# 18261       2815.13223       5968.57        3338.36          57762.43
# 18262       4514.08964       6042.83        3649.00          62063.18
# 18263       2275.72271       6600.36        3958.51          66407.19
#
#        industry_car  service_car  cluster_7  cluster_2
# 0           2853.19      3058.03          3          1
# 1           2853.19      3058.03          3          1
# 2           2853.19      3058.03          3          1
# 3           2853.19      3058.03          3          1
# 4           2853.19      3058.03          3          1
# 5           2853.19      3058.03          3          1
# 6           2853.19      3058.03          3          1
# 7           2853.19      3058.03          3          1
# 8           2853.19      3058.03          3          1
# 9           2853.19      3058.03          3          1
# 10          2853.19      3058.03          3          1
# 11          2853.19      3058.03          3          1
# 12          2853.19      3058.03          3          1
# 13          2853.19      3058.03          3          1
# 14          2853.19      3058.03          3          1
# 15          2853.19      3058.03          3          1
# 16          2853.19      3058.03          3          1
# 17          2853.19      3058.03          3          1
# 18          2853.19      3058.03          3          1
# 19          2853.19      3058.03          3          1
# 21          2853.19      3058.03          3          1
# 22          2853.19      3058.03          3          1
# 23          2853.19      3058.03          3          1
# 24          2853.19      3058.03          3          1
# 25          2853.19      3058.03          3          1
# 26          2853.19      3058.03          3          1
# 27          2853.19      3058.03          3          1
# 28          2853.19      3058.03          3          1
# 29          2853.19      3058.03          3          1
# 30          2853.19      3058.03          3          1
# ...             ...          ...        ...        ...
# 18234       6850.66      7922.24          5          1
# 18235       6862.38      7927.79          5          1
# 18236       7146.03      8749.12          5          1
# 18237       6511.75      7913.45          5          1
# 18238       6469.42      7412.65          5          1
# 18239       6923.58      8372.83          5          1
# 18240       6923.58      8372.83          5          1
# 18241       6923.58      8372.83          5          1
# 18242       2389.44      2488.29          3          1
# 18243       2389.44      2488.29          3          1
# 18244       2389.44      2488.29          3          1
# 18245       2389.44      2488.29          3          1
# 18246       2389.44      2488.29          3          1
# 18247       2389.44      2488.29          3          1
# 18248       2389.44      2488.29          3          1
# 18249       2389.44      2488.29          3          1
# 18250       2389.44      2488.29          3          1
# 18251       2389.44      2488.29          3          1
# 18252       2389.44      2488.29          3          1
# 18253       2389.44      2488.29          3          1
# 18254       2389.44      2488.29          3          1
# 18255       2389.44      2488.29          3          1
# 18256       2389.44      2488.29          3          1
# 18257       2853.19      3058.03          3          1
# 18258       2853.19      3058.03          3          1
# 18259       2853.19      3058.03          3          1
# 18260       5435.38      6613.75          5          1
# 18261       5435.38      6613.75          5          1
# 18262       5250.73      5949.97          5          1
# 18263       5801.05      6574.54          5          1
#
# [17841 rows x 28 columns]

# %% [markdown]
# ## 1.6 Standardize Currency Units
# `avg_zone_income` is in Million Chilean Peso. However, `monthly_rent` and `household_income` are in Chilean Peso. We would like to standardize `avg_zone_income` to Chilean Peso.

# %%
df['avg_zone_income'] =  df['avg_zone_income'] * 1000000

# %% [markdown]
# ## 1.7 Utilize Coordinate Data
# The coordinate data given in the data set is in UTM format. It is of little help to us because it only pinpoints the geographical location of each data point. We have to quantify it into some more useful information such that it can be used as a feature into any machine learning algorithm.
#
# For example, one way is to obtain the distance between a location and the city center.
#
# In order to obtain the distance, we resort to Google Maps API. Unfortunately, Google Maps API does not support UTM format. Thus, we need to convert UTM into latitude and longitude information. Luckily, Python has a package named `utm` that helps us do the job (https://github.com/Turbo87/utm).

# %% [markdown]
# ### 1.7.1 Convert UTM Format To Lat/Lon Format

# %% [markdown]
# We define a function to convert UTM format to Lat/Lon format.
#
# Since the dataset does not contain zone and latitude band information for Santiago, we read up online (https://www.gps-latitude-longitude.com/gps-coordinates-of-santiago-de-chile) and learn that the zone is 19 and latitude band is 'H'.

# %%
def getLatLon(east, north):
    return utm.to_latlon(east, north, 19, 'H')

# %% [markdown]
# Again, we define a function to extract lat/lon information and store this information into two new columns, `latitude` and `longitude`.

# %%
def LatLonColumns():
    res=[]
    east=df.UTM_East.tolist()
    north=df.UTM_North.tolist()
    for i in range(len(east)):
        res.append(getLatLon(east[i],north[i]))
    return res

# %%
res = LatLonColumns()
latitude = list(map(lambda x : x[0], res))
longitude = list(map(lambda x : x[1], res))

# %%
df['latitude'] = latitude
df['longitude'] = longitude

# %% [markdown]
# With latitude and longtitude information, we do not need UTM information any more.

# %%
df = df.drop(['UTM_East', 'UTM_North'], axis = 1)

# %% [markdown]
# ### 1.7.2 Obtain Distance to City Center with Google Maps API

# %% [markdown]
# In order to get the latitude and longitude information of the city center, we search for Santiago, Chile on Google Maps (https://www.google.dk/maps/place/Santiago,+Santiago+Metropolitan+Region,+Chile/@-33.4724228,-70.7699155,11z/data=!3m1!4b1!4m13!1m7!3m6!1s0x9662c5410425af2f:0x8475d53c400f0931!2sSantiago,+Santiago+Metropolitan+Region,+Chile!3b1!8m2!3d-33.4488897!4d-70.6692655!3m4!1s0x9662c5410425af2f:0x8475d53c400f0931!8m2!3d-33.4488897!4d-70.6692655) and use the coordinates of the search result as the location of the city center. Its latitude is -33.446896, and longitude is -70.673124.

# %% [markdown]
# Next, our group uses Google Maps API to obtain:
# * Distance between each housing to the city center, by driving

# %%
# Google map api key
APIKey="your api here"

# %% [markdown]
# We define a function which takes in latitude and longitude of a place and returns the distance and duration to travel to city center of Santiago by car.

# %%
def getDisDur(lat,lon):
    response = requests.get('https://maps.googleapis.com/maps/api/distancematrix/json',
                            params={'units': 'metric',
                                    'origins' : str(lat) + ',' + str(lon),
                                    'destinations' : '-33.446896,-70.673124',
                                    'key' : APIKey})
    data=response.json()['rows'][0]['elements'][0]
    distance=data['distance']['value']
    return distance

# %% [markdown]
# The function below runs API calls thousands of time, we store the data requested into dataframe. As such, the function below only needs to be run once.

# %%
# def DisDurCol():
#     latitude=df.latitude.tolist()
#     longitude=df.longitude.tolist()
#     res=[]
#     for i in range(len(latitude)):
#         res.append(getDisDur(latitude[i],longitude[i]))
#         if i % 1000 == 0:
#             print(i)
#     return res
# res=DisDurCol()

# %% [markdown]
# We extract distance and time taken data and store in corresponding columns.

# %%
# df['Distance_CityCenter']=list(map(lambda x : x[0], res))

# %% [markdown]
# Export the cleaned dataset into csv. Next time, we will just load this csv file.

# %%
# df.to_csv("cleaned_data.csv")

# %% [markdown]
# ### 1.7.3 Test to Load csv

# %%
df_test=pd.read_csv("cleaned_data.csv", index_col = 0)

# %%
df_test.head()
# Out:
#        ID  exogenous_sector  monthly_rent  household_income  survey_factor  \
# 0  100010                 7        100000            450845     136.393738
# 1  100020                 7        120000           1019369      73.843597
# 2  100030                 7         70000             80000     180.722809
# 3  100041                 7         80000            559259     150.379059
# 4  100052                 7        117771            710309     122.001518
#
#    education_years  type  built_surface  construction_quality  build_density  \
# 0               11     1           53.8                  0.98          0.059
# 1               11     1           59.6                  0.98          0.033
# 2               10     1           59.5                  0.98          0.004
# 3               14     2           59.5                  0.98          0.004
# 4               12     2           43.6                  0.98          0.086
#
#    ...  education_car  habitational_car  industry_car  service_car  cluster_7  \
# 0  ...        1781.81          30505.65       2853.19      3058.03          3
# 1  ...        1781.81          30505.65       2853.19      3058.03          3
# 2  ...        1781.81          30505.65       2853.19      3058.03          3
# 3  ...        1781.81          30505.65       2853.19      3058.03          3
# 4  ...        1781.81          30505.65       2853.19      3058.03          3
#
#    cluster_2   latitude  longitude  Distance_CityCenter  Time_taken
# 0          1 -33.729444 -70.779035                38682        2415
# 1          1 -33.737278 -70.744340                35583        2056
# 2          1 -33.805994 -70.859656                53214        3104
# 3          1 -33.805995 -70.859654                53214        3104
# 4          1 -33.722055 -70.743270                36504        2099
#
# [5 rows x 30 columns]

# %% [markdown]
# # 2. Exploratary Data Analysis (EDA)

# %% [markdown]
# ## 2.1 Summary Statistics

# %%
df_test.describe()
# Out:
#                   ID  exogenous_sector  monthly_rent  household_income  \
# count   18264.000000      18264.000000  1.826400e+04      1.826400e+04
# mean   193030.230672          3.821288  1.915436e+05      6.882743e+05
# std     56198.257546          1.947325  1.642392e+05      7.287777e+05
# min    100010.000000          1.000000  1.000000e+04      0.000000e+00
# 25%    145647.750000          2.000000  1.136745e+05      3.000000e+05
# 50%    192085.500000          4.000000  1.500000e+05      5.078265e+05
# 75%    237732.750000          6.000000  2.000000e+05      8.411012e+05
# max    743823.000000          7.000000  5.000000e+06      1.480000e+07
#
#        survey_factor  education_years          type  built_surface  \
# count   18264.000000     18264.000000  18264.000000   18264.000000
# mean      112.314389         9.776555     -0.321124      50.352858
# std        74.540944        16.400822     14.556300      23.019691
# min         5.151379       -99.000000    -99.000000       0.000000
# 25%        67.999544        10.000000      1.000000      39.100000
# 50%        94.457756        12.000000      2.000000      45.800000
# 75%       133.587433        14.000000      2.000000      58.000000
# max       927.142761        24.000000      3.000000     207.300000
#
#        construction_quality  build_density  ...  education_car  \
# count          18264.000000   18264.000000  ...   18264.000000
# mean               0.640918       0.383019  ...    3389.102833
# std                0.353851       0.461823  ...     857.208576
# min                0.000000       0.000000  ...     -99.000000
# 25%                0.360000       0.177000  ...    3062.360000
# 50%                0.780000       0.256000  ...    3538.740000
# 75%                0.980000       0.363000  ...    3989.947500
# max                1.000000       4.599000  ...    4681.260000
#
#        habitational_car  industry_car   service_car     cluster_7  \
# count      18264.000000  18264.000000  18264.000000  18264.000000
# mean       58147.204716   5073.627695   6307.223734      3.899365
# std        14062.171453   1298.025692   1930.571354      1.538586
# min          -99.000000    -99.000000    -99.000000      1.000000
# 25%        53163.070000   4508.790000   5091.160000      2.000000
# 50%        61218.910000   5267.610000   6452.625000      5.000000
# 75%        68388.830000   5980.780000   7699.100000      5.000000
# max        75774.780000   7260.030000  10000.680000      7.000000
#
#           cluster_2      latitude     longitude  Distance_CityCenter  \
# count  18264.000000  18264.000000  18264.000000         18264.000000
# mean       1.152541    -33.495396    -70.673004         18280.069536
# std        0.359554      0.096568      0.110020         11879.120285
# min        1.000000    -33.810955    -71.321708           200.000000
# 25%        1.000000    -33.563749    -70.728089          9865.000000
# 50%        1.000000    -33.488603    -70.657311         16539.500000
# 75%        1.000000    -33.430608    -70.596949         23773.000000
# max        2.000000    -33.177505    -70.286672        100074.000000
#
#          Time_taken
# count  18264.000000
# mean    1483.320905
# std      581.581882
# min       48.000000
# 25%     1093.000000
# 50%     1400.000000
# 75%     1803.000000
# max     5279.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# # 3. Define functions for fitted model
# (Logistic Regression/KNN/Linear Regression)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
def logistic_reg_model(X_train, X_test, y_train):
    
    classifier = LogisticRegression()
    classifier.fit(X_train,y_train)
    y_pred1 = classifier.predict(X_test)
    
    return y_pred1

# %%
def linear_regression(X_train, X_test, y_train):
    
    classifier = LinearRegression()
    classifier.fit(X_train,y_train)
    y_pred2 = classifier.predict(X_test)
    
    return y_pred2

# %%
def knn_model(X_train, X_test, y_train, n):
    
    classifier = KNeighborsClassifier(n_neighbors = n)
    classifier.fit(X_train,y_train)
    y_pred3 = classifier.predict(X_test)
    
    return y_pred3
